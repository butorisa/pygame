# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, Reshape
from keras.optimizers import Adam
from keras.regularizers import l2

from rl.agents.dqn import DQNAgent
from rl.policy import EpsGreedyQPolicy
from rl.memory import SequentialMemory
import cupcake_game

# ゲームクラスをロード
env = cupcake_game.Game(step=True, image=True)
# プレイヤーの行動種類数（上下左右の移動）
nb_actions = 4

# CNNで使うパラメータ
hidden_size = 128
n_filters = 8
kernel = (13, 13)
strides = (3, 3)

# CNNモデル
model = Sequential()
model.add(Reshape((env.observation_space.shape), input_shape=(1,) + env.observation_space.shape))
model.add(Conv2D(n_filters, kernel, strides=strides, activation='relu', padding='same'))
model.add(Conv2D(n_filters, kernel, strides=strides, activation='relu', padding='same'))
model.add(Conv2D(n_filters, kernel, strides=strides, activation='relu', padding='same'))
model.add(Flatten())
model.add(Dense(hidden_size, kernel_initializer='he_normal', activation='relu',
                kernel_regularizer=l2(0.01)))
model.add(Dense(hidden_size, kernel_initializer='he_normal', activation='relu',
                kernel_regularizer=l2(0.01)))
model.add(Dense(hidden_size, kernel_initializer='he_normal', activation='relu',
                kernel_regularizer=l2(0.01)))
model.add(Dense(nb_actions, activation='linear'))
print(model.summary())

memory = SequentialMemory(limit=100000, window_length=1)
policy = EpsGreedyQPolicy(eps=0.001)

# DQNモデル
dqn = DQNAgent(model=model, nb_actions=nb_actions, gamma=0.99, memory=memory, nb_steps_warmup=100,
               target_model_update=1e-2, policy=policy)

dqn.compile(Adam(lr=1e-3), metrics=['mae'])

# パラメータの重みを保存しているファイル
fname = "cupcake_dqn_weights.bin"
try:
    dqn.load_weights(fname)
    print("Weights are loaded.")
except:
    print("Weights are NOT loaded.")

# 学習実行
history = dqn.fit(env, nb_steps=1000, verbose=2)

dqn.save_weights(fname, overwrite=True)

# テスト実行
dqn.test(env, nb_episodes=10)
# Out:
# Using TensorFlow backend.
# C:\Users\user\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# WARNING:tensorflow:From C:\Users\user\.conda\envs\keras\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 151, 120, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 51, 40, 8)         4064
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 14, 8)         10824
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 5, 8)           10824
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 240)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               30848
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 90,100
# Trainable params: 90,100
# Non-trainable params: 0
# _________________________________________________________________
# None
# Weights are NOT loaded.
# Training for 1000 steps ...
# WARNING:tensorflow:From C:\Users\user\.conda\envs\keras\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#  113/1000: episode: 1, duration: 21.506s, episode steps: 113, steps per second: 5, episode reward: 1.000, mean reward: 0.009 [0.000, 1.000], mean action: 0.991 [0.000, 2.000], mean observation: 163.104 [0.000, 255.000], loss: 477.879637, mae: 43.390730, mean_q: 75.076667
#  146/1000: episode: 2, duration: 21.753s, episode steps: 33, steps per second: 2, episode reward: -10.000, mean reward: -0.303 [-10.000, 0.000], mean action: 1.515 [1.000, 2.000], mean observation: 166.836 [0.000, 255.000], loss: 76.371208, mae: 25.942402, mean_q: 50.832474
#  179/1000: episode: 3, duration: 21.468s, episode steps: 33, steps per second: 2, episode reward: 1.000, mean reward: 0.030 [0.000, 1.000], mean action: 1.333 [0.000, 2.000], mean observation: 160.456 [0.000, 255.000], loss: 98.866493, mae: 16.783958, mean_q: 31.041311
#  213/1000: episode: 4, duration: 21.664s, episode steps: 34, steps per second: 2, episode reward: 1.000, mean reward: 0.029 [0.000, 1.000], mean action: 1.029 [0.000, 2.000], mean observation: 164.677 [0.000, 255.000], loss: 19.077370, mae: 5.454661, mean_q: 12.629930
#  246/1000: episode: 5, duration: 21.213s, episode steps: 33, steps per second: 2, episode reward: -10.000, mean reward: -0.303 [-10.000, 0.000], mean action: 0.758 [0.000, 2.000], mean observation: 166.432 [0.000, 255.000], loss: 6.190872, mae: 2.732071, mean_q: 6.243061
#  279/1000: episode: 6, duration: 21.668s, episode steps: 33, steps per second: 2, episode reward: -10.000, mean reward: -0.303 [-10.000, 0.000], mean action: 1.636 [0.000, 2.000], mean observation: 167.946 [0.000, 255.000], loss: 6.112964, mae: 2.621797, mean_q: 4.974315
#  313/1000: episode: 7, duration: 21.476s, episode steps: 34, steps per second: 2, episode reward: -10.000, mean reward: -0.294 [-10.000, 0.000], mean action: 2.000 [2.000, 2.000], mean observation: 171.893 [0.000, 255.000], loss: 5.979977, mae: 2.938588, mean_q: 6.229937
#  343/1000: episode: 8, duration: 21.523s, episode steps: 30, steps per second: 1, episode reward: -10.000, mean reward: -0.333 [-10.000, 0.000], mean action: 2.000 [2.000, 2.000], mean observation: 172.067 [0.000, 255.000], loss: 6.080712, mae: 3.070126, mean_q: 6.263597
#  373/1000: episode: 9, duration: 21.286s, episode steps: 30, steps per second: 1, episode reward: -10.000, mean reward: -0.333 [-10.000, 0.000], mean action: 1.500 [0.000, 2.000], mean observation: 170.989 [0.000, 255.000], loss: 6.584746, mae: 3.004340, mean_q: 6.138978
#  407/1000: episode: 10, duration: 21.406s, episode steps: 34, steps per second: 2, episode reward: -10.000, mean reward: -0.294 [-10.000, 0.000], mean action: 1.853 [0.000, 2.000], mean observation: 171.505 [0.000, 255.000], loss: 6.767876, mae: 2.828560, mean_q: 6.193958
#  441/1000: episode: 11, duration: 21.712s, episode steps: 34, steps per second: 2, episode reward: -10.000, mean reward: -0.294 [-10.000, 0.000], mean action: 1.676 [1.000, 2.000], mean observation: 168.848 [0.000, 255.000], loss: 6.953520, mae: 2.702376, mean_q: 5.984197
#  475/1000: episode: 12, duration: 21.560s, episode steps: 34, steps per second: 2, episode reward: -10.000, mean reward: -0.294 [-10.000, 0.000], mean action: 1.676 [1.000, 2.000], mean observation: 166.185 [0.000, 255.000], loss: 6.599371, mae: 2.747213, mean_q: 5.783464
#  509/1000: episode: 13, duration: 21.557s, episode steps: 34, steps per second: 2, episode reward: -10.000, mean reward: -0.294 [-10.000, 0.000], mean action: 1.971 [1.000, 2.000], mean observation: 166.185 [0.000, 255.000], loss: 6.444884, mae: 2.626646, mean_q: 5.702160
#  543/1000: episode: 14, duration: 21.698s, episode steps: 34, steps per second: 2, episode reward: -10.000, mean reward: -0.294 [-10.000, 0.000], mean action: 1.971 [1.000, 2.000], mean observation: 166.185 [0.000, 255.000], loss: 6.079114, mae: 2.599864, mean_q: 5.594116
#  577/1000: episode: 15, duration: 21.470s, episode steps: 34, steps per second: 2, episode reward: -10.000, mean reward: -0.294 [-10.000, 0.000], mean action: 1.235 [0.000, 2.000], mean observation: 167.516 [0.000, 255.000], loss: 6.547704, mae: 2.626070, mean_q: 5.348156
#  610/1000: episode: 16, duration: 21.594s, episode steps: 33, steps per second: 2, episode reward: -10.000, mean reward: -0.303 [-10.000, 0.000], mean action: 1.727 [1.000, 2.000], mean observation: 166.247 [0.000, 255.000], loss: 6.741866, mae: 2.437272, mean_q: 5.312013
#  643/1000: episode: 17, duration: 21.251s, episode steps: 33, steps per second: 2, episode reward: -10.000, mean reward: -0.303 [-10.000, 0.000], mean action: 0.394 [0.000, 2.000], mean observation: 167.408 [0.000, 255.000], loss: 6.538355, mae: 2.416157, mean_q: 5.019097
#  677/1000: episode: 18, duration: 21.662s, episode steps: 34, steps per second: 2, episode reward: -10.000, mean reward: -0.294 [-10.000, 0.000], mean action: 1.382 [0.000, 2.000], mean observation: 166.562 [0.000, 255.000], loss: 6.317898, mae: 2.463712, mean_q: 5.086160
#  709/1000: episode: 19, duration: 21.388s, episode steps: 32, steps per second: 1, episode reward: -10.000, mean reward: -0.312 [-10.000, 0.000], mean action: 1.250 [0.000, 2.000], mean observation: 167.527 [0.000, 255.000], loss: 6.806909, mae: 2.325288, mean_q: 4.744767
#  742/1000: episode: 20, duration: 21.386s, episode steps: 33, steps per second: 2, episode reward: -10.000, mean reward: -0.303 [-10.000, 0.000], mean action: 1.485 [0.000, 2.000], mean observation: 170.356 [0.000, 255.000], loss: 6.280087, mae: 2.267115, mean_q: 4.563971
#  774/1000: episode: 21, duration: 21.618s, episode steps: 32, steps per second: 1, episode reward: 1.000, mean reward: 0.031 [0.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: 164.849 [0.000, 255.000], loss: 5.971650, mae: 2.260535, mean_q: 4.632874
#  807/1000: episode: 22, duration: 21.688s, episode steps: 33, steps per second: 2, episode reward: 1.000, mean reward: 0.030 [0.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: 164.794 [0.000, 255.000], loss: 6.039139, mae: 2.258950, mean_q: 4.398384
#  840/1000: episode: 23, duration: 21.237s, episode steps: 33, steps per second: 2, episode reward: 1.000, mean reward: 0.030 [0.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: 164.794 [0.000, 255.000], loss: 6.250738, mae: 2.243757, mean_q: 4.410833
#  874/1000: episode: 24, duration: 21.723s, episode steps: 34, steps per second: 2, episode reward: 1.000, mean reward: 0.029 [0.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: 164.742 [0.000, 255.000], loss: 6.958624, mae: 2.145422, mean_q: 4.156997
#  907/1000: episode: 25, duration: 21.170s, episode steps: 33, steps per second: 2, episode reward: 1.000, mean reward: 0.030 [0.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: 164.794 [0.000, 255.000], loss: 6.199006, mae: 2.071837, mean_q: 4.233021
#  941/1000: episode: 26, duration: 21.717s, episode steps: 34, steps per second: 2, episode reward: 1.000, mean reward: 0.029 [0.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: 164.742 [0.000, 255.000], loss: 5.565477, mae: 2.163740, mean_q: 4.379556
#  974/1000: episode: 27, duration: 21.297s, episode steps: 33, steps per second: 2, episode reward: 1.000, mean reward: 0.030 [0.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: 164.794 [0.000, 255.000], loss: 5.596841, mae: 2.074233, mean_q: 4.266328
# done, took 597.278 seconds
# Testing for 10 episodes ...
# Episode 1: reward: 1.000, steps: 180
# Episode 2: reward: 1.000, steps: 180
# Episode 3: reward: 1.000, steps: 179
# Episode 4: reward: 1.000, steps: 181
# Episode 5: reward: 1.000, steps: 179
# Episode 6: reward: 1.000, steps: 179
# Episode 7: reward: 1.000, steps: 180
# Episode 8: reward: 1.000, steps: 180
# Episode 9: reward: 1.000, steps: 179
# Episode 10: reward: 1.000, steps: 181
